# %% [markdown]
# Welcome to Jupyter Notebook, where we'll do the next stage of the DQA interview. This is a collaborative and open-book test, so ask lots of questions and feel free to look up syntax of function calls and APIs.

# %% [markdown]
# The data is in a file named dqa_interview_input_data.csv
#
# Libraries including matplotlib, numpy, csv, and pandas can be imported.

# %% [markdown]
# # Question 1: Read in and parse "dqa_interview_input_data.csv". Calculate the system performance for each row.
#
# (by "performance" we mean ratio of energy actually produced to energy budgeted:  `actualkwh / budgetkwh` .)

# %%
from matplotlib import pyplot as plt
data_file_name = "dqa_interview_input_data.csv"

# Your Python code for question 1 here. All blocks on the page are a shared Python scope,
# so variables you define in this block retain their value in later blocks.

# %% [markdown]
# # Question 2: Make a plot of performance versus system size.  ("size" is the total power of the system in kilowatts.)
#
# (Bonus question: can you make the chart easier to read by removing outliers?)

# %%
# Your Python code for question 2 here.



# For reference, the basic syntax for making a scatter plot with matplotlib is like so:
plt.scatter( array_of_x_values, array_of_y_values )

# %% [markdown]
# # Question 3: Make a bar chart of average performance for each zip code
#
# (Bonus question: a bar chart of just the five highest-performing zip codes)

# %%
# Your Python code for question 3 here.


# For reference, the basic syntax for making a bar chart with matplotlib is like so:
plt.bar( array_of_labels, array_of_bar_heights )

# %% [markdown]
# # Extra credit: How would you save the above results (average PI for each zip code) to a database?
#
# (There is no actual database connection in this jupyter notebook, so this will just be pseudocode.
# Can you show what schema you'd create for the table, and an example query of that table?)
