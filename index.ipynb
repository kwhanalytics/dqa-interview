# %% [markdown]
# Welcome to Jupyter Notebook, where we'll do the next stage of the DQA interview.

# %% [markdown]
# The data file is named dqa_interview_input_data.csv
#
# Libraries including matplotlib, numpy, csv, and pandas can be imported.

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# For reference, the basic syntax for making a plot with matplotlib is like so...
# scatter plot:
# > plt.scatter( array_of_x_values, array_of_y_values )
#
# bar chart:
# > plt.bar( array_of_labels, array_of_values )
#
# histogram:
# > plt.hist( array_of_values )
#
# etc.

# %% [markdown]
# # Question 1: Read in and parse "dqa_interview_input_data.csv". Calculate the PI for each system.
#
# ("PI", "performance index", is the ratio of energy actually produced to energy budgeted:  actualkwh / budgetkwh.
# Capacity is the "size" of the system in kilowatts.)

# %% [markdown]
# # Question 2: Make a plot PI versus capacity.
#
# (Bonus question: can you make the chart easier to read by removing outliers?)

# %% [markdown]
# # Question 3: Make a bar chart of average PI for each zip code
#
# (Bonus question: a bar chart of just the ten highest-performing zip codes)

# %% [markdown]
# # Extra credit: How would you save the above results (average PI for each zip code) to a database?
#
# (There is no actual database connection in this jupyter notebook, so this will just be pseudocode.
# Can you show what schema you'd create for the table, and an example query of that table?)
